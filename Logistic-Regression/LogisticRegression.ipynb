# %% [markdown]
# # Logistic Regression

# %% [markdown]
# ![logistic_regression](./logisticregression.png)

# %% [markdown]
# ### Logistic Regression is a Supervised statistical technique to find the probability of dependent variable,used to predict observations to a discrete set of classes
#
# ###  Logistic Regression is also called **Logit Regression**
#
# ### **Logit functions**,that helps derive a relationship between the dependent variable and independent variables by predicting the probabilities or chances of occurrence.

# %% [markdown]
# ## Types of Logistic Regression:
#
# ### **Binary Logistic Regression**:
# ### The dependent variable has only two 2 possible outcomes/classes. Example-Male or Female.
# ### **Multinomial Logistic Regression**:
# ### The dependent variable has only two 3 or more possible outcomes/classes without ordering.Example: Predicting food quality.(Good,Great and Bad).
# ### **Ordinal Logistic Regression**:
# ### The dependent variable has only two 3 or more possible outcomes/classes with ordering

# %% [markdown]
# ## Why not Linear Regression for Classification?
#
#
# ### Linear Regression predicts continuous variables like price of house,and the output of the Linear Regression can range from negative infinity to positive infinity.
# ### The predicted values is not probability value but a continuous value for the classes,it will be very hard to find the right threshold that can help distinguish between the classes.
# ### If the problem would be multi-class it will not give the desirable prediction

# %% [markdown]
# ## The Logistic Model

# %% [markdown]
# ### The Logistic Regression instead for fitting the best fit line,condenses the output of the linear function between 0 and 1.
#
# ![logistic-model](./logisticmodel.png)

# %% [markdown]
# ## Odds Ratio and Logit

# %% [markdown]
# ### **Odds**: the odds in favor of a particular event
#
# ### Odds are the ratio of the probability of success to the probability of failure
# ## $\frac{p}{1-p}$
#
# ### Assume the probability of success is 0.6.
# ### So,probability of failure will be (1–0.6) = 0.4
#
# ### Odds are determined from probabilities and range between 0 to ∞.
# ###  odds(Success) = $\frac{p}{(1-p)}$ or $\frac{p}{q} = \frac{0.6}{0.4} = 1.5$
# ### odds(Failure) = $\frac{0.4}{0.6} = 0.66667$

# %% [markdown]
# ## Logit Function

# %% [markdown]
# ### Logit function is simply the logarithm of the odds
# ## $logit(p)=\log\frac{p}{1-p}$
#
# ### In Logistic regression we can calculate odds ratio between the classes:
#
# ## $e^{\log(\frac{p}{1-p})}=\frac{p}{1-p}$
# ## $\frac{p}{1-p}=\frac{p}{1-p}\\ p=(1+p)e^{\log(\frac{p}{1-p})}\\ p=e^{\log(\frac{p}{1-p})}-pe^{\log(\frac{p}{1-p})}\\p(1+e^{\log(\frac{p}{1-p})})=e^{\log(\frac{p}{1-p})}\\p=\frac{e^{\log(\frac{p}{1-p})}}{1+e^{\log(\frac{p}{1-p})}}\\p=\frac{1}{1+e^{\frac{1}{\log(\frac{p}{1-p})}}}\\p=\frac{1}{1+e^-{\log(\frac{p}{1-p})}}\\p=\frac{1}{1+e^{-w^Tx}}$
#
#
# ### The logit function takes input values in the range 0 to 1 andtransforms them to values over the entire real-number range, which we can use to express a linear relationship between feature values and the log-odds
#
# ## $logit(p(y=1|x))=w_0x_0+w_1x_1+\dots+w_mx_m=\sum_{i=0}^{m} w_ix_i=w^Tx$
#
# ### $p(y=1|x)$ is the conditional probability that a particular example belongs to class $1$ given its features $x$

# %% [markdown]
# ### We are actually interested in predicting the probability that a certain example belongs to a particular class, which is the inverse form of the logit function.
# ### It is also called the **logistic sigmoid function**, which is sometimes simply abbreviated to **sigmoid function**
# ## $\phi(z)=\frac{1}{1+e^-z}$
# ### $z$ is the net input
# ## $z=w_0x_0+w_1x_1+\dots+w_mx_m=\sum_{i=0}^{m} w_ix_i=w^Tx$

# %%
import matplotlib.pyplot as plt
import numpy as np
def sigmoid(z):

    return 1.0 / (1.0 + np.exp(-z))
z = np.arange(-7, 7, 0.1)
phi_z = sigmoid(z)
plt.plot(z, phi_z)
plt.axvline(0.0, color='k')
plt.ylim(-0.1, 1.1)
plt.xlabel('z')
plt.ylabel('$\phi (z)$')
# y axis ticks and gridline
plt.yticks([0.0, 0.5, 1.0])
ax = plt.gca()
ax.yaxis.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### The difference between Adaline and logistic regression
# ![adalinevslogistic](./adalinevslogistic.png)

# %% [markdown]
# ### The output of the sigmoid function is then interpreted as the probability of a particular example belonging to class 1,
# ## $\phi(z)=p(y=1|x;w)$
#
# ### $p(y|x;w)$ is a conditional probability distribution, which means it represents the probability of event $y$ occurring given that event $x$ has already occurred
# ### In other words, $p(y|x;w)$ tells us how likely it is that the model will output $y$ given that it has seen input $x$.
# ### given its features $x$ parameterized by the weights $w$
# ### The predicted probability can then simply be converted into a binary outcome via a threshold function
#
# ## $ \hat{y}=  \{1 if \phi(z)\geq 0.5 ,0 otherwise$

# %% [markdown]
# ## Learning the weights of the logistic cost function

# %% [markdown]
# ### Cost Function is a function that measures the performance of a Machine Learning model for given data.
# ### Cost Function is the average of error of n-sample in the data.
# ### Loss Function is the error for individual data points.
# ### In other words,Loss Function is for one training example,Cost Function is the for the entire training set.

# %% [markdown]
# ## Why we Can not use the Cost function of the Linear Regression?

# %% [markdown]
# ### Trying to use a cost function of the Linear Regression model using the Mean Squared Error will give a non-Convex function,which will give a weirdly shaped graph that looks like this.
# ![cost-lr](./costfoflr.png)
#
# ### This graphs has many local minimums which makes it very hard for the cost function to reach global minimum and minimize the error.
#
# ![local-minima](./localminima.png)

# %% [markdown]
# ### Let's briefly talk about how we fit the parameters of the model, for instance the weights, $w$
# ### Sum squared error function :
# ## $J(w)=\frac{1}{2}\sum_i(\phi(z^{(i)})-y^{(i)})^2$
# ### We minimized this function in order to learn the weights, w, for our Adaline classification model

# %% [markdown]
# ## Likelihood
# ### Likelihood, L, that we want to maximize when we build a logistic regression model, assuming that the individual examples in our dataset are independent of one another.
# ### The Maximum Likelihood Estimation (MLE) is a method of estimating the parameters of a logistic regression model.
# ### The method of maximum likelihood selects the set of values of the model parameters that maximize the likelihood function.
#
# ## $L(w)=p(y|x;w)=\\\prod_{i=1}^n p(y^{(i)}|x^{(i)};w)\\=\prod_{i=1}^n(\phi(z^{(i)})^{y^{(i)}})(1-\phi(z^{(i)}))^{1-y^{(i)}}$

# %% [markdown]
# ## Log-likelihood
#
# ## $l(w)=\log L(w)=\sum_{i=1}^n[y^{(i)}\log(\phi(z^{(i)}))+(1-y^{(i)})\log(1-\phi(z^{(i)}))]$

# %% [markdown]
# ### Firstly, applying the log function reduces the potential for numerical underflow,which can occur if the likelihoods are very small. Secondly, we can convert the product of factors into a summation of factors, which makes it easier to obtain the derivative of this function

# %% [markdown]
# ### We could use an optimization algorithm such as gradient ascent to maximize this log-likelihood function.

# %% [markdown]
# ## $l(w)=\log L(w)=\sum_{i=1}^n[-y^{(i)}\log(\phi(z^{(i)}))-(1-y^{(i)})\log(1-\phi(z^{(i)}))]$

# %% [markdown]
# ### The cost that we calculate for one single training example:
# ## $J(\phi(z),y;w)=-y\log(\phi(z))-(1-y)\log(1-\phi(z))$
# ### we can see that the first term becomes zero if $y = 0$, and the second term becomes zero if $y = 1$
# ## $J(\phi(z),y;w)=\{-\log(\phi(z)), if, y=1\\-\log(1-\phi(z))if, y=0$
# ### This is why Cost function for Logistic Regression is
# ![cost-function](./costfunction.png)

# %%
def cost_1(z):
    return - np.log(sigmoid(z))
def cost_0(z):

    return - np.log(1 - sigmoid(z))
z = np.arange(-10, 10, 0.1)
phi_z = sigmoid(z)
c1 = [cost_1(x) for x in z]
plt.plot(phi_z, c1, label='J(w) if y=1')
c0 = [cost_0(x) for x in z]
plt.plot(phi_z, c0, linestyle='--', label='J(w) if y=0')
plt.ylim(0.0, 5.1)
plt.xlim([0, 1])
plt.xlabel('$\phi$(z)')
plt.ylabel('J(w)')
plt.legend(loc='best')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## The gradient descent learning algorithm for logistic regression

# %% [markdown]
# ### Partial Derivatives of the Log-Likelihood function with respect to $jth$ weight
# ## $\frac{\partial}{\partial w_j}=(y\frac{1}{\phi(z)}-(1-y)\frac{1}{(1-\phi(z))})\frac{\partial}{\partial w_j}\phi(z)$
# ### Partial Derivative of **Sigmoid Function**
# ## $\frac{\partial}{\partial z}=\frac{\partial}{\partial z}\frac{1}{1+e^{-z}}\\=\frac{1}{(1+e^{-z})^2}e^-z\\=\frac{1}{1+e^{-z}}(1-\frac{1}{1+e^{-z}})\\=\phi(z)(1-\phi(z))$

# %% [markdown]
# ### Substitute $\frac{\partial}{\partial w_j}$ with $\phi(z)(1-\phi(z))$ in the first equation
# ## $(y\frac{1}{\phi(z)}-(1-y)\frac{1}{(1-\phi(z))})\frac{\partial}{\partial w_j}\phi(z)\\=(y\frac{1}{\phi(z)}-(1-y)\frac{1}{(1-\phi(z))})\phi(z)(1-\phi(z))\frac{\partial}{\partial w_j}z\\=(y(1-\phi(z)))x_j\\=(y-\phi(z))x_j$

# %% [markdown]
# ### the goal is to find the weights that maximize the log-likelihood so that we perform the update for each weight as follows
# ## $w_j:=w_j+\eta\sum_{i=1}^n(y^{(i)}-\phi(z^{(i)}))x_j^{(i)}$
#
#
# ### General Update Rule
# ## $w:=w+\Delta w$
# ## $\Delta w=\eta\nabla l(w)$

# %% [markdown]
# ### Maximizing the log-likelihood is equal to minimizing the cost function, $J$, that we defined earlier, we can write the gradient descent update rule as follows:
# ## $\Delta w_j=-\eta\frac{\partial J}{\partial w_j}\\=\eta\sum_{i=1}^n(y^{(i)}-\phi(z^{i}))x_j^{i}$
#
# ### $w:=w+\Delta w, \Delta w=-\eta \nabla J(w)$

# %%
from matplotlib.colors import ListedColormap
import matplotlib.pyplot as plt
def plot_decision_regions(X, y, classifier, test_idx=None,
resolution=0.02):
# setup marker generator and color map
    markers = ('s', 'x', 'o', '^', 'v')
    colors = ('red', 'blue', 'lightgreen', 'gray', 'cyan')
    cmap = ListedColormap(colors[:len(np.unique(y))])
# plot the decision surface
    x1_min, x1_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    x2_min, x2_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx1, xx2 = np.meshgrid(np.arange(x1_min, x1_max, resolution),
    np.arange(x2_min, x2_max, resolution))
    Z = classifier.predict(np.array([xx1.ravel(), xx2.ravel()]).T)
    Z = Z.reshape(xx1.shape)
    plt.contourf(xx1, xx2, Z, alpha=0.3, cmap=cmap)
    plt.xlim(xx1.min(), xx1.max())
    plt.ylim(xx2.min(), xx2.max())
    for idx, cl in enumerate(np.unique(y)):
        plt.scatter(x=X[y == cl, 0], y=X[y == cl, 1],
        alpha=0.8, c=colors[idx],
        marker=markers[idx], label=cl,
    edgecolor='black')
    if test_idx: 
        X_test, y_test = X[test_idx, :], y[test_idx]
        plt.scatter(X_test[:, 0], X_test[:, 1],
c='', edgecolor='black', alpha=1.0,
linewidth=1, marker='o',
s=100, label='test set')

# %%
class LogisticRegressionGD(object):
    def __init__(self, eta=0.05, n_iter=100, random_state=1):
        self.eta = eta
        self.n_iter = n_iter
        self.random_state = random_state
    def fit(self, X, y):
        rgen = np.random.RandomState(self.random_state)
        self.w_ = rgen.normal(loc=0.0, scale=0.01,
        size=1 + X.shape[1])
        self.cost_ = []
        for i in range(self.n_iter):
            net_input = self.net_input(X)
            output = self.activation(net_input)
            errors = (y - output)
            self.w_[1:] += self.eta * X.T.dot(errors)
            self.w_[0] += self.eta * errors.sum()

            cost = (-y.dot(np.log(output)) -((1 - y).dot(np.log(1 - output))))
            self.cost_.append(cost)
        return self
    def net_input(self, X):

        return np.dot(X, self.w_[1:]) + self.w_[0]
    def activation(self, z):
        return 1. / (1. + np.exp(-np.clip(z, -250, 250)))

    def predict(self, X):
        return np.where(self.net_input(X) >= 0.0, 1, 0)

# %%
from sklearn import datasets
import numpy as np
iris = datasets.load_iris()
X = iris.data[:, [2, 3]]
y = iris.target
print('Class labels:', np.unique(y))
# Out:
# Class labels: [0 1 2]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(

X, y, test_size=0.3, random_state=1, stratify=y)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
sc.fit(X_train)
X_train_std = sc.transform(X_train)
X_test_std = sc.transform(X_test)

# %%
X_train_01_subset = X_train[(y_train == 0) | (y_train == 1)]
y_train_01_subset = y_train[(y_train == 0) | (y_train == 1)]
lrgd = LogisticRegressionGD(eta=0.05,

n_iter=1000,
random_state=1)
lrgd.fit(X_train_01_subset,
y_train_01_subset)
plot_decision_regions(X=X_train_01_subset,
y=y_train_01_subset,
classifier=lrgd)
plt.xlabel('petal length [standardized]')
plt.ylabel('petal width [standardized]')
plt.legend(loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_16052/3501630105.py:20: UserWarning: You passed a edgecolor/edgecolors ('black') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   plt.scatter(x=X[y == cl, 0], y=X[y == cl, 1],

# %% [markdown]
# ## Training a logistic regression model with scikit-learn

# %%
from sklearn.linear_model import LogisticRegression
X_combined_std = np.vstack((X_train_std, X_test_std))
y_combined = np.hstack((y_train, y_test))
lr = LogisticRegression(C=100.0, random_state=1,

solver='lbfgs', multi_class='ovr')
lr.fit(X_train_std, y_train)
plot_decision_regions(X_combined_std,
y_combined,
classifier=lr,
test_idx=range(105, 150))
plt.xlabel('petal length [standardized]')
plt.ylabel('petal width [standardized]')
plt.legend(loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_16052/3501630105.py:20: UserWarning: You passed a edgecolor/edgecolors ('black') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   plt.scatter(x=X[y == cl, 0], y=X[y == cl, 1],
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/matplotlib/axes/_axes.py:4375, in Axes._parse_scatter_color_args(c, edgecolors, kwargs, xsize, get_next_color_func)
#    4374 try:  # Is 'c' acceptable as PathCollection facecolors?
# -> 4375     colors = mcolors.to_rgba_array(c)
#    4376 except (TypeError, ValueError) as err:
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/colors.py:471, in to_rgba_array(c, alpha)
#     470 if isinstance(c, str):
# --> 471     raise ValueError(f"{c!r} is not a valid color value.")
#     473 if len(c) == 0:
#
# ...

# %% [markdown]
# ## Tackling overfitting via regularization

# %% [markdown]
# ## Overfitting:
# ### Overfitting is a common problem in machine learning, where a model performs well on training data but does not generalize well to unseen data (test data). If a model suffers from overfitting, we also say that the model has a high variance, which can be caused by having too many parameters, leading to a model that is too complex given the underlying data

# %% [markdown]
# ## Underfitting
# ### our model can also suffer from underfitting (high bias), which means that our model is not complex enough to capture the pattern in the training data well and therefore also suffers from low performance on unseen data.
# ![under-over-fitting](./underoverfittin.png)

# %% [markdown]
# ## Variance
# ### Variance measures the consistency (or variability) of the model prediction for classifying a particular example if we retrain the model multiple times
# ## Bias
#
# ### Bias measures how far off the predictions are from the correct values in general if we rebuild the model multiple times on different training datasets; bias is the measure of the systematic error that is not due to randomness.

# %% [markdown]
# ## Bias-variance tradeoff

# %% [markdown]
# ![bias-variance](./biasvariance.png)
#
# ## Regularization
#
# ### The concept behind regularization is to introduce additional information (bias) to penalize extreme parameter (weight) values.
#
# ### Regularization is a way to tune the complexity of the model
# ### Regularization helps to filter out noise from training data
# ### regularization prevents overfitting
# ## L2 Regularization
#
# ## $=\frac{\lambda}{2}|||w||^2$
# ### To apply regularization, we add the regularization term to the cost function, which shrinks the weights
# ### $l(w)=\log L(w)=\sum_{i=1}^n[-y^{(i)}\log(\phi(z^{(i)}))-(1-y^{(i)})\log(1-\phi(z^{(i)}))]+\frac{\lambda}{2}|||w||^2 $
# ### The derivative of w 2 with respect to w is 2w
# ## $w_i=w_i-\eta\frac{\partial J}{\partial w_i}-\eta \lambda w_i$

# %% [markdown]
# ### $\eta\lambda w_i$ coming from the regularization causes the weight to decay in proportion to its size
# ### We control how well we fit the training data via the regularization parameter $\lambda$
#
# ### **By increasing $\lambda$ we increase the strength of regularization**

# %%
weights, params = [], []
for c in np.arange(-5, 5):

    lr = LogisticRegression(C=10.**c, random_state=1,

    solver='lbfgs', multi_class='ovr')

    lr.fit(X_train_std, y_train)

    weights.append(lr.coef_[1])

    params.append(10.**c)
weights = np.array(weights)
plt.plot(params, weights[:, 0],

label='petal length')
plt.plot(params, weights[:, 1], linestyle='--',

label='petal width')
plt.ylabel('weight coefficient')
plt.xlabel('C')
plt.legend(loc='upper left')
plt.xscale('log')
plt.show()

# %% [markdown]
# ### As we can see in the resulting plot, the weight coefficients shrink if we decrease if we increase the regularization strength:
